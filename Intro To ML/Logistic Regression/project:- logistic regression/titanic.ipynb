# %%
import numpy as np
import pandas as pd

# %%
titanic = pd.read_csv('train.csv')
titanic.tail(50)
# Out:
#      Pclass                                               Name     Sex    Age  \
# 618       3                           Jussila, Miss. Mari Aina  female  21.00
# 619       2                               Bracken, Mr. James H    male  27.00
# 620       2                      Silven, Miss. Lyyli Karoliina  female  18.00
# 621       3                                 Markoff, Mr. Marin    male  35.00
# 622       1  Thayer, Mrs. John Borland (Marian Longstreth M...  female  39.00
# 623       1           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.00
# 624       1                        Williams, Mr. Charles Duane    male  51.00
# 625       1                      Aubart, Mme. Leontine Pauline  female  24.00
# 626       2                        Christy, Miss. Julie Rachel  female  25.00
# 627       1                            Fleming, Miss. Margaret  female    NaN
# 628       3                                 Dennis, Mr. Samuel    male  22.00
# ...

# %%
df= titanic.copy(deep=True)

df.drop(columns=['Name','Ticket','Cabin'],inplace=True)
df.head()

# df.describe()
# Out:
#    Pclass     Sex   Age  SibSp  Parch    Fare Embarked  Survived
# 0       2  female  29.0      1      0  26.000        S         1
# 1       3    male   NaN      0      0   8.050        S         0
# 2       2    male  39.0      0      0  26.000        S         0
# 3       3  female  29.0      0      4  21.075        S         0
# 4       3    male  25.0      0      0   7.050        S         0

# %%
df['Sex'].replace('male',1,inplace=True)
df['Sex'].replace('female',0,inplace=True)


df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Embarked'].replace('S',0,inplace=True)
df['Embarked'].replace('Q',1,inplace = True)
df['Embarked'].replace('C',2,inplace = True)


df['Embarked'].fillna(df['Embarked'].mean(),inplace=True)
df.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare  \
# count  668.000000  668.000000  668.000000  668.000000  668.000000  668.000000
# mean     2.296407    0.639222   29.700560    0.528443    0.407186   32.064552
# std      0.831638    0.480586   12.753571    1.080327    0.854695   45.320835
# min      1.000000    0.000000    0.670000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000   23.000000    0.000000    0.000000    7.925000
# 50%      3.000000    1.000000   29.700560    0.000000    0.000000   14.750000
# 75%      3.000000    1.000000   35.000000    1.000000    0.000000   31.275000
# max      3.000000    1.000000   80.000000    8.000000    6.000000  512.329200
#
#          Embarked    Survived
# count  668.000000  668.000000
# mean     0.473763    0.402695
# std      0.805054    0.490808
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      1.000000    1.000000
# ...

# %%
data = df.to_numpy()

# %%
X = data[:,0:7]
Y = data[:,7]
X
# Out:
# array([[ 2.       ,  0.       , 29.       , ...,  0.       , 26.       ,
#          0.       ],
#        [ 3.       ,  1.       , 29.7005597, ...,  0.       ,  8.05     ,
#          0.       ],
#        [ 2.       ,  1.       , 39.       , ...,  0.       , 26.       ,
#          0.       ],
#        ...,
#        [ 3.       ,  1.       , 32.       , ...,  0.       , 56.4958   ,
#          0.       ],
#        [ 3.       ,  0.       , 22.       , ...,  0.       ,  9.8375   ,
#          0.       ],
#        [ 3.       ,  0.       , 29.7005597, ...,  0.       , 15.5      ,
#          1.       ]])

# %%
from sklearn import model_selection


X_train,X_test,Y_train,Y_test = model_selection.train_test_split(X,Y,test_size=0.3)

len(X_train),len(X_test)
# Out:
# (467, 201)

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()
clf.fit(X_train_scaled,Y_train)
# Out:
# LogisticRegression()

# %%
clf.score(X_train_scaled,Y_train)
# Out:
# 0.7858672376873662

# %%
clf.score(X_test_scaled,Y_test)
# Out:
# 0.8009950248756219

# %%
testing = pd.read_csv("test.csv")

# %%
testing.drop(columns=['Name','Ticket','Cabin'],inplace=True)
testing['Embarked'].replace('S',0,inplace=True)
testing['Embarked'].replace('Q',1,inplace = True)
testing['Embarked'].replace('C',2,inplace = True)

testing['Sex'].replace('male',1,inplace=True)
testing['Sex'].replace('female',0,inplace=True)


testing['Embarked'].fillna(df['Embarked'].mean(),inplace=True)

# %%
testing['Age'].fillna(testing['Age'].mean(),inplace=True)

testing.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare  \
# count  223.000000  223.000000  223.000000  223.000000  223.000000  223.000000
# mean     2.345291    0.672646   29.694775    0.506726    0.304933   32.622551
# std      0.850047    0.470303   13.749153    1.169700    0.634108   61.062047
# min      1.000000    0.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000   22.000000    0.000000    0.000000    7.879200
# 50%      3.000000    1.000000   29.694775    0.000000    0.000000   12.475000
# 75%      3.000000    1.000000   35.000000    1.000000    0.000000   30.035400
# max      3.000000    1.000000   71.000000    8.000000    2.000000  512.329200
#
#          Embarked
# count  223.000000
# mean     0.437102
# std      0.749229
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      2.000000

# %%
test_data = testing.to_numpy()

# %%
scale_test_data = scaler.transform(test_data)

# %%
predictions = clf.predict(scale_test_data)

# %%
np.savetxt('predictions.csv',predictions)
